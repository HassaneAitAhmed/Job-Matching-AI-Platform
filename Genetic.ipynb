# %%
import pandas as pd
import numpy as np
import math
from typing import List, Dict, Tuple

# Global constants
EDU_RANK = {'Bac': 0, 'Bachelor': 1, 'License': 2, 'Master': 3, 'PhD': 4}

# ---------- 1. Data Loading & Preparation ----------
def load_data() -> Tuple[pd.DataFrame, pd.DataFrame]:
    try:
        seekers_df = pd.read_csv('emplo.csv')[[
            'gender', 'birth_date', 'age', 'city', 'department',
            'sector', 'years_experience', 'highest_education',
            'contract_type', 'technical_skills', 'language_proficiency',
            'education_history', 'edu_value', 'salary'
        ]]
    except FileNotFoundError:
        seekers_df = pd.DataFrame([{
            'gender': 'Male', 'birth_date': '1990-05-15', 'age': 33,
            'city': 'Algiers', 'department': 'IT', 'sector': 'Technology',
            'years_experience': 5, 'highest_education': 'Master',
            'contract_type': 'Full-time', 'technical_skills': 'Python, SQL, Spark',
            'language_proficiency': 'English, French', 'education_history': 'University of Algiers',
            'edu_value': 3, 'salary': 70000
        }])

    jobs_df = pd.DataFrame([
        {'job_id': 'DEV-001', 'required_skills': ['HYSYS', 'Communication', 'Problem Solving'],
         'min_education': 'License', 'min_experience': 3, 'salary_offer': 75000,
         'location': 'Algiers', 'sector': 'Energy & Petroleum', 'contract_type': 'CDD'},
        {'job_id': 'DATA-002', 'required_skills': ['python', 'Problem Solving', 'Teamwork'],
         'min_education': 'Bachelor', 'min_experience': 2, 'salary_offer': 65000,
         'location': 'Oran', 'sector': 'Data Science', 'contract_type': 'CDD'}
    ])
    
    return seekers_df, jobs_df

# ---------- 2. Core Matching Functions ----------
def preprocess_data(seekers_df: pd.DataFrame, jobs_df: pd.DataFrame) -> Tuple:
    """Preprocess and normalize all data for matching"""
    # Education ranking
    seekers_df['edu_rank'] = seekers_df['highest_education'].map(EDU_RANK).fillna(-1).astype(int)
    jobs_df['edu_rank'] = jobs_df['min_education'].map(EDU_RANK).fillna(-1).astype(int)

    # Skills processing
    seekers_df['technical_skills'] = seekers_df['technical_skills'].fillna('').str.lower()
    seeker_skills = [set(s.split(', ')) for s in seekers_df['technical_skills']]
    job_skills = [set(map(str.lower, req)) for req in jobs_df['required_skills']]

    # Sector and contract type normalization
    all_sectors = pd.Categorical(seekers_df['sector'].tolist() + jobs_df['sector'].tolist())
    seek_sector_codes = pd.Categorical(seekers_df['sector'], categories=all_sectors.categories).codes
    job_sector_codes = pd.Categorical(jobs_df['sector'], categories=all_sectors.categories).codes

    contract_types = pd.Categorical(seekers_df['contract_type'].tolist() + jobs_df['contract_type'].tolist())
    seek_cont_codes = pd.Categorical(seekers_df['contract_type'], categories=contract_types.categories).codes
    job_cont_codes = pd.Categorical(jobs_df['contract_type'], categories=contract_types.categories).codes

    return seekers_df, jobs_df, seeker_skills, job_skills, seek_sector_codes, job_sector_codes, seek_cont_codes, job_cont_codes

def calculate_features(seekers_df, jobs_df, seeker_skills, job_skills, seek_sector_codes, job_sector_codes, seek_cont_codes, job_cont_codes) -> np.ndarray:
    """Calculate all feature scores between seekers and jobs"""
    N_seek = len(seekers_df)
    N_job = len(jobs_df)
    F_raw = np.zeros((N_seek, N_job, 7), dtype=np.float32)

    # Skill TF-IDF calculation
    all_skills = [skill for skills in seekers_df['technical_skills'] for skill in skills.split(', ') if skill]
    skill_counts = pd.Series(all_skills).value_counts()
    total_docs = N_seek + N_job
    skill_idf = {s: np.log((total_docs + 1)/(cnt + 1)) + 1 for s, cnt in skill_counts.items()}

    # Salary normalization
    all_salaries = np.concatenate([seekers_df['salary'].values, jobs_df['salary_offer'].values])
    max_sal = np.percentile(all_salaries, 95)
    min_sal = np.percentile(all_salaries, 5)

    for i in range(N_seek):
        for j in range(N_job):
            # Skill match (40%)
            common_skills = seeker_skills[i] & job_skills[j]
            missing_skills = job_skills[j] - seeker_skills[i]
            penalty = 1 - (len(missing_skills) / len(job_skills[j]))
            match_score = sum(skill_idf.get(s, 0) for s in common_skills)
            total_score = sum(skill_idf.get(s, 0) for s in job_skills[j])
            F_raw[i,j,0] = penalty * (match_score / total_score if total_score > 0 else 0)

            # Experience (15%)
            F_raw[i,j,1] = min(seekers_df.at[i,'years_experience'] / max(jobs_df.at[j,'min_experience'], 1), 1.5)

            # Salary (15%)
            salary_diff = abs(jobs_df.at[j,'salary_offer'] - seekers_df.at[i,'salary'])
            F_raw[i,j,2] = 1 - np.log1p(salary_diff) / np.log1p(max_sal - min_sal)

            # Education (10%)
            F_raw[i,j,3] = seekers_df.at[i,'edu_rank'] / max(EDU_RANK.values())

            # Sector (10%)
            F_raw[i,j,4] = (seek_sector_codes[i] == job_sector_codes[j])

            # Contract (5%)
            F_raw[i,j,5] = (seek_cont_codes[i] == job_cont_codes[j])

            # Education value (5%)
            F_raw[i,j,6] = seekers_df.at[i,'edu_value'] / 20

    # Min-Max Normalization
    feature_mins = F_raw.min(axis=(0,1))
    feature_maxs = F_raw.max(axis=(0,1))
    F = (F_raw - feature_mins) / (feature_maxs - feature_mins + 1e-8)
    
    return F

# ---------- 3. Genetic Algorithm Implementation ----------
def initialize_population(pop_size: int, N_seek: int, valid_jobs: np.ndarray) -> np.ndarray:
    """Initialize population with valid job assignments"""
    pop = np.empty((pop_size, N_seek), dtype=int)
    for i in range(N_seek):
        choices = np.append(np.where(valid_jobs[i])[0], -1)  # -1 means no job
        pop[:,i] = np.random.choice(choices, pop_size)
    return pop

def calculate_fitness(pop: np.ndarray, F: np.ndarray, weights: np.ndarray) -> np.ndarray:
    """Calculate fitness scores for population"""
    scores = np.zeros(pop.shape[0])
    for k in range(pop.shape[0]):
        for i in range(pop.shape[1]):
            j = pop[k,i]
            if j >= 0:  # Only count if assigned to a valid job
                scores[k] += F[i,j].dot(weights)
        # Penalize unmatched candidates
        scores[k] -= 0.1 * np.sum(pop[k] == -1)
    return scores

def tournament_selection(pop: np.ndarray, fitness: np.ndarray, tournament_size: int = 3) -> np.ndarray:
    """Select parents using tournament selection"""
    selected = np.empty_like(pop)
    for i in range(pop.shape[0]):
        contenders = np.random.choice(len(fitness), tournament_size, replace=False)
        winner = pop[contenders[np.argmax(fitness[contenders])]]
        selected[i] = winner
    return selected

def crossover(parent1: np.ndarray, parent2: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
    """Perform crossover between two parents"""
    if len(parent1) <= 1:
        return parent1.copy(), parent2.copy()
    cut = np.random.randint(1, len(parent1))
    child1 = np.concatenate([parent1[:cut], parent2[cut:]])
    child2 = np.concatenate([parent2[:cut], parent1[cut:]])
    return child1, child2

def mutate(chromosome: np.ndarray, mutation_rate: float, valid_jobs: np.ndarray) -> np.ndarray:
    """Mutate chromosome with given rate"""
    for i in range(len(chromosome)):
        if np.random.rand() < mutation_rate:
            choices = np.append(np.where(valid_jobs[i])[0], -1)
            chromosome[i] = np.random.choice(choices)
    return chromosome

def run_genetic_algorithm(F: np.ndarray, weights: np.ndarray, valid_jobs: np.ndarray,
                         pop_size: int = 50, generations: int = 100,
                         mutation_rate: float = 0.1, elite_size: int = 2) -> Tuple[np.ndarray, float]:
    """Run the complete genetic algorithm"""
    N_seek = F.shape[0]
    pop = initialize_population(pop_size, N_seek, valid_jobs)
    best_score = -np.inf
    best_solution = None
    
    for gen in range(generations):
        # Evaluate fitness
        fitness = calculate_fitness(pop, F, weights)
        
        # Track best solution
        current_best = np.argmax(fitness)
        if fitness[current_best] > best_score:
            best_score = fitness[current_best]
            best_solution = pop[current_best].copy()
        
        # Selection
        selected = tournament_selection(pop, fitness)
        
        # Crossover
        new_pop = []
        for i in range(0, pop_size - elite_size, 2):
            p1, p2 = selected[i], selected[i+1]
            c1, c2 = crossover(p1, p2)
            new_pop.extend([c1, c2])
        
        # Elitism
        elites = pop[np.argsort(fitness)[-elite_size:]]
        new_pop.extend(elites)
        
        # Mutation
        for i in range(len(new_pop)):
            new_pop[i] = mutate(new_pop[i], mutation_rate, valid_jobs)
        
        pop = np.array(new_pop)[:pop_size]  # Ensure population size stays constant
        
        print(f"Generation {gen+1}/{generations} | Best Score: {best_score:.2f}", end='\r')
    
    print()  # New line after progress updates
    return best_solution, best_score

# ---------- 4. Main Execution ----------
if __name__ == '__main__':
    # Load and preprocess data
    seekers_df, jobs_df = load_data()
    seekers_df, jobs_df, seeker_skills, job_skills, seek_sector_codes, job_sector_codes, seek_cont_codes, job_cont_codes = preprocess_data(seekers_df, jobs_df)
    
    # Calculate feature matrix
    F = calculate_features(seekers_df, jobs_df, seeker_skills, job_skills, 
                         seek_sector_codes, job_sector_codes, seek_cont_codes, job_cont_codes)
    
    # Define weights for each feature
    WEIGHTS = np.array([0.40, 0.15, 0.15, 0.10, 0.10, 0.05, 0.05], dtype=np.float32)
    
    # Create valid jobs matrix
    valid_jobs = (
    (seekers_df['edu_rank'].values[:, None] >= jobs_df['edu_rank'].values[None, :]) &
    (seekers_df['years_experience'].values[:, None] >= jobs_df['min_experience'].values[None, :]) &
    np.array([
        [len(seeker_skills[i] & job_skills[j]) >= max(1, len(job_skills[j]) // 2) for j in range(len(jobs_df))]
        for i in range(len(seekers_df))
    ])
    )

    
    # Run genetic algorithm
    best_solution, best_score = run_genetic_algorithm(F, WEIGHTS, valid_jobs)
    
    # Display results
    print("\nBest Solution Score:", best_score)
    print("\nOptimal Matches:")
    for i, job_idx in enumerate(best_solution):
        if job_idx >= 0:  # Only show actual matches
            seeker = seekers_df.iloc[i]
            job = jobs_df.iloc[job_idx]
            
            # Calculate match details
            common_skills = seeker_skills[i] & job_skills[job_idx]
            missing_skills = job_skills[job_idx] - seeker_skills[i]
            sector_match = seeker['sector'] == job['sector']
            contract_match = seeker['contract_type'] == job['contract_type']
            
            print(f"\nSeeker {i} → Job {job['job_id']}")
            print(f"  Skills: {len(common_skills)}/{len(job_skills[job_idx])} matched")
            if missing_skills:
                print(f"  Missing Skills: {', '.join(missing_skills)}")
            print(f"  Sector: {'Match' if sector_match else f'Mismatch (Seeker: {seeker["sector"]}, Job: {job["sector"]})'}")
            print(f"  Contract: {'Match' if contract_match else f'Mismatch (Seeker: {seeker["contract_type"]}, Job: {job["contract_type"]})'}")
            print(f"  Experience: {seeker['years_experience']}y (Req: {job['min_experience']}y)")
            print(f"  Education: {seeker['highest_education']} (Req: {job['min_education']})")
            print(f"  Salary: Seeker ${seeker['salary']:,} vs Job Offer ${job['salary_offer']:,}")
    
    # Show top candidates per job
    print("\nTop Candidates per Job:")
    for j in range(len(jobs_df)):
        job = jobs_df.iloc[j]
        scores = F[:,j].dot(WEIGHTS)
        valid = valid_jobs[:,j]
        ranked = sorted([(i, scores[i]) for i in np.where(valid)[0]], key=lambda x: -x[1])[:5]
        
        print(f"\nJob {job['job_id']} ({job['sector']}):")
        for rank, (i, score) in enumerate(ranked, 1):
            seeker = seekers_df.iloc[i]
            common_skills = seeker_skills[i] & job_skills[j]
            print(f"{rank}. [Score: {score:.2%}] {seeker['technical_skills']}")
            print(f"   Sector: {seeker['sector']} | Exp: {seeker['years_experience']}y | Edu: {seeker['highest_education']}")
            print(f"   Matching Skills: {', '.join(common_skills)}")
# Out:
# Generation 100/100 | Best Score: 139.29
#
# Best Solution Score: 139.29462311565874
#
# Optimal Matches:
#
# Seeker 1 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: E-Commerce, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 6y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $96,200.0 vs Job Offer $75,000
#
# Seeker 5 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Aerospace & Defense, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 36y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $134,800.0 vs Job Offer $75,000
#
# Seeker 6 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: teamwork, python
#   Sector: Mismatch (Seeker: E-Commerce, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 13y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $105,600.0 vs Job Offer $65,000
#
# Seeker 18 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Retail, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Alternance, Job: CDD)
#   Experience: 31y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $122,500.0 vs Job Offer $75,000
#
# Seeker 26 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Renewable Energy, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 28y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $115,200.0 vs Job Offer $65,000
#
# Seeker 32 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Education, Job: Data Science)
#   Contract: Match
#   Experience: 23y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $75,600.0 vs Job Offer $65,000
#
# Seeker 33 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Aerospace & Defense, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 25y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $92,400.0 vs Job Offer $65,000
#
# Seeker 39 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Tourism & Hospitality, Job: Data Science)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 18y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $77,700.0 vs Job Offer $65,000
#
# Seeker 40 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: problem solving, hysys
#   Sector: Mismatch (Seeker: Renewable Energy, Job: Energy & Petroleum)
#   Contract: Match
#   Experience: 3y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $53,900.0 vs Job Offer $75,000
#
# Seeker 44 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Retail, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Alternance, Job: CDD)
#   Experience: 21y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $84,000.0 vs Job Offer $75,000
#
# Seeker 48 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: teamwork, python
#   Sector: Mismatch (Seeker: Fisheries, Job: Data Science)
#   Contract: Match
#   Experience: 18y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $77,700.0 vs Job Offer $65,000
#
# Seeker 50 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Transport & Logistics, Job: Data Science)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 20y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $95,600.0 vs Job Offer $65,000
#
# Seeker 55 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Telecommunications, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 30y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $120,100.0 vs Job Offer $75,000
#
# Seeker 59 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: problem solving, hysys
#   Sector: Mismatch (Seeker: Agriculture, Job: Energy & Petroleum)
#   Contract: Match
#   Experience: 19y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $93,100.0 vs Job Offer $75,000
#
# Seeker 60 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Mining, Job: Data Science)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 13y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $78,400.0 vs Job Offer $65,000
#
# Seeker 73 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: teamwork, python
#   Sector: Mismatch (Seeker: Energy & Petroleum, Job: Data Science)
#   Contract: Match
#   Experience: 2y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $88,200.0 vs Job Offer $65,000
#
# Seeker 78 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Agriculture, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 32y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $124,900.0 vs Job Offer $65,000
#
# Seeker 81 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Match
#   Contract: Mismatch (Seeker: Alternance, Job: CDD)
#   Experience: 29y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $201,600.0 vs Job Offer $75,000
#
# Seeker 83 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Tourism & Hospitality, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 33y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $127,400.0 vs Job Offer $75,000
#
# Seeker 89 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Transport & Logistics, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 5y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $50,400.0 vs Job Offer $65,000
#
# Seeker 90 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Banking & Finance, Job: Energy & Petroleum)
#   Contract: Match
#   Experience:
(Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $127,400.0 vs Job Offer $65,000
#
# Seeker 549 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: teamwork, python
#   Sector: Mismatch (Seeker: Education, Job: Data Science)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 11y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $54,000.0 vs Job Offer $65,000
#
# Seeker 550 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: problem solving, python
#   Sector: Mismatch (Seeker: Construction, Job: Data Science)
#   Contract: Match
#   Experience: 10y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $85,300.0 vs Job Offer $65,000
#
# Seeker 557 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Transport & Logistics, Job: Data Science)
#   Contract: Match
#   Experience: 4y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $48,300.0 vs Job Offer $65,000
#
# Seeker 567 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: problem solving, python
#   Sector: Mismatch (Seeker: Transport & Logistics, Job: Data Science)
#   Contract: Match
#   Experience: 5y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $58,800.0 vs Job Offer $65,000
#
# Seeker 573 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Tourism & Hospitality, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 34y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $129,900.0 vs Job Offer $75,000
#
# Seeker 574 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Tourism & Hospitality, Job: Data Science)
#   Contract: Mismatch (Seeker: CDI, Job: CDD)
#   Experience: 27y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $112,700.0 vs Job Offer $65,000
#
# Seeker 576 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: problem solving, python
#   Sector: Mismatch (Seeker: Agriculture, Job: Data Science)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 22y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $86,100.0 vs Job Offer $65,000
#
# Seeker 577 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: problem solving, python
#   Sector: Mismatch (Seeker: Transport & Logistics, Job: Data Science)
#   Contract: Match
#   Experience: 9y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $68,600.0 vs Job Offer $65,000
#
# Seeker 582 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: problem solving, python
#   Sector: Mismatch (Seeker: Manufacturing, Job: Data Science)
#   Contract: Match
#   Experience: 13y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $85,100.0 vs Job Offer $65,000
#
# Seeker 583 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Information Technology, Job: Data Science)
#   Contract: Match
#   Experience: 11y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $63,000.0 vs Job Offer $65,000
#
# Seeker 587 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: problem solving, python
#   Sector: Mismatch (Seeker: Telecommunications, Job: Data Science)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 21y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $84,000.0 vs Job Offer $65,000
#
# Seeker 590 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: problem solving, hysys
#   Sector: Mismatch (Seeker: Aerospace & Defense, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 6y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $61,200.0 vs Job Offer $75,000
#
# Seeker 592 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: problem solving, hysys
#   Sector: Mismatch (Seeker: Media & Entertainment, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 6y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $78,700.0 vs Job Offer $75,000
#
# Seeker 593 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Education, Job: Data Science)
#   Contract: Match
#   Experience: 35y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $113,400.0 vs Job Offer $65,000
#
# Seeker 595 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: hysys, communication
#   Sector: Mismatch (Seeker: Pharmaceuticals, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 6y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $52,500.0 vs Job Offer $75,000
#
# Seeker 597 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: problem solving, python
#   Sector: Mismatch (Seeker: Pharmaceuticals, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 4y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $56,300.0 vs Job Offer $65,000
#
# Seeker 599 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Mining, Job: Data Science)
#   Contract: Match
#   Experience: 30y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $102,900.0 vs Job Offer $65,000
#
# Seeker 607 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: teamwork, python
#   Sector: Mismatch (Seeker: Information Technology, Job: Data Science)
#   Contract: Match
#   Experience: 22y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $86,100.0 vs Job Offer $65,000
#
# Seeker 608 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Renewable Energy, Job: Data Science)
#   Contract: Match
#   Experience: 18y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $90,600.0 vs Job Offer $65,000
#
# Seeker 614 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Construction, Job: Data Science)
#   Contract: Mismatch (Seeker: CDI, Job: CDD)
#   Experience: 35y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $158,800.0 vs Job Offer $65,000
#
# Seeker 619 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: problem solving, python
#   Sector: Mismatch (Seeker: Information Technology, Job: Data Science)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 13y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $78,400.0 vs Job Offer $65,000
#
# Seeker 621 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: problem solving, hysys
#   Sector: Mismatch (Seeker: Mining, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 15y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $83,300.0 vs Job Offer $75,000
#
# Seeker 622 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Media & Entertainment, Job: Data Science)
#   Contract: Match
#   Experience: 5y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $64,800.0 vs Job Offer $65,000
#
# Seeker 626 → Job DATA-002
# ...
#   Salary: Seeker $111,700.0 vs Job Offer $65,000
#
# Seeker 7964 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: problem solving, hysys
#   Sector: Mismatch (Seeker: Tourism & Hospitality, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: CDI, Job: CDD)
#   Experience: 11y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $63,000.0 vs Job Offer $75,000
#
# Seeker 7970 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Retail, Job: Energy & Petroleum)
#   Contract: Match
#   Experience: 21y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $84,000.0 vs Job Offer $75,000
#
# Seeker 7978 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: teamwork, python
#   Sector: Mismatch (Seeker: Healthcare, Job: Data Science)
#   Contract: Match
#   Experience: 6y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $67,500.0 vs Job Offer $65,000
#
# Seeker 7979 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: teamwork, python
#   Sector: Mismatch (Seeker: Pharmaceuticals, Job: Data Science)
#   Contract: Match
#   Experience: 30y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $102,900.0 vs Job Offer $65,000
#
# Seeker 7981 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: problem solving, hysys
#   Sector: Mismatch (Seeker: Media & Entertainment, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 6y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $67,500.0 vs Job Offer $75,000
#
# Seeker 7987 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Education, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 30y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $88,200.0 vs Job Offer $75,000
#
# Seeker 7989 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: problem solving, hysys
#   Sector: Mismatch (Seeker: Tourism & Hospitality, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: CDI, Job: CDD)
#   Experience: 22y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $86,100.0 vs Job Offer $75,000
#
# Seeker 7992 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Healthcare, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 7y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $81,900.0 vs Job Offer $65,000
#
# Seeker 7997 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: problem solving, hysys
#   Sector: Mismatch (Seeker: Pharmaceuticals, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 11y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $63,000.0 vs Job Offer $75,000
#
# Seeker 7998 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: problem solving, hysys
#   Sector: Mismatch (Seeker: Pharmaceuticals, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Alternance, Job: CDD)
#   Experience: 30y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $102,900.0 vs Job Offer $75,000
#
# Seeker 8004 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: hysys, communication
#   Sector: Mismatch (Seeker: E-Commerce, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: CDI, Job: CDD)
#   Experience: 10y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $111,600.0 vs Job Offer $75,000
#
# Seeker 8008 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: teamwork, python
#   Sector: Mismatch (Seeker: Manufacturing, Job: Data Science)
#   Contract: Match
#   Experience: 17y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $82,100.0 vs Job Offer $65,000
#
# Seeker 8009 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: teamwork, python
#   Sector: Mismatch (Seeker: Renewable Energy, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 13y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $78,400.0 vs Job Offer $65,000
#
# Seeker 8010 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Energy & Petroleum, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 34y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $222,600.0 vs Job Offer $65,000
#
# Seeker 8016 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: problem solving, python
#   Sector: Mismatch (Seeker: Manufacturing, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 36y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $146,300.0 vs Job Offer $65,000
#
# Seeker 8019 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: teamwork, python
#   Sector: Mismatch (Seeker: Healthcare, Job: Data Science)
#   Contract: Match
#   Experience: 24y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $135,400.0 vs Job Offer $65,000
#
# Seeker 8024 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: hysys, communication
#   Sector: Mismatch (Seeker: Healthcare, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 12y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $83,700.0 vs Job Offer $75,000
#
# Seeker 8025 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Pharmaceuticals, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 20y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $81,900.0 vs Job Offer $75,000
#
# Seeker 8026 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Transport & Logistics, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 38y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $119,700.0 vs Job Offer $65,000
#
# Seeker 8028 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: teamwork
#   Sector: Mismatch (Seeker: Information Technology, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 30y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $120,100.0 vs Job Offer $65,000
#
# Seeker 8029 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: problem solving, hysys
#   Sector: Mismatch (Seeker: Renewable Energy, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 27y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $112,700.0 vs Job Offer $75,000
#
# Seeker 8033 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Healthcare, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 7y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $81,900.0 vs Job Offer $65,000
#
# Seeker 8037 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: E-Commerce, Job: Energy & Petroleum)
#   Contract: Match
#   Experience: 16y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $134,800.0 vs Job Offer $75,000
#
# Seeker 8042 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Retail, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: CDI, Job: CDD)
#   Experience: 24y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $105,400.0 vs Job Offer $75,000
#
# Seeker 8050 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Retail, Job: Energy & Petroleum)
#   Contract: Match
#   Experience: 16y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $85,800.0 vs Job Offer $75,000
#
# Seeker 8052 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: teamwork, python
#   Sector: Mismatch (Seeker: Construction, Job: Data Science)
#   Contract: Match
#   Experience: 15y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $100,000.0 vs Job Offer $65,000
#
# Seeker 8055 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: problem solving, python
#   Sector: Mismatch (Seeker: Telecommunications, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 11y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $63,000.0 vs Job Offer $65,000
#
# Seeker 8058 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: problem solving, hysys
#   Sector: Mismatch (Seeker: E-Commerce, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 3y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $84,700.0 vs Job Offer $75,000
#
# Seeker 8074 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: problem solving, hysys
#   Sector: Mismatch (Seeker: Banking & Finance, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 16y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $73,500.0 vs Job Offer $75,000
#
# Seeker 8085 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: hysys, communication
#   Sector: Mismatch (Seeker: Banking & Finance, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 17y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $75,600.0 vs Job Offer $75,000
#
# Seeker 8090 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Transport & Logistics, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 15y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $83,300.0 vs Job Offer $65,000
#
# Seeker 8091 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: E-Commerce, Job: Data Science)
#   Contract: Match
#   Experience: 31y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $165,000.0 vs Job Offer $65,000
#
# Seeker 8098 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: problem solving, python
#   Sector: Mismatch (Seeker: Aerospace & Defense, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 4y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $56,300.0 vs Job Offer $65,000
#
# Seeker 8101 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: teamwork, python
#   Sector: Mismatch (Seeker: Information Technology, Job: Data Science)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 22y (Req: 2y)
#   Education: License (Req: Bachelor)
#   Salary: Seeker $86,100.0 vs Job Offer $65,000
#
# Seeker 8104 → Job DATA-002
#   Skills: 2/3 matched
#   Missing Skills: python
#   Sector: Mismatch (Seeker: Public Sector, Job: Data Science)
#   Contract: Mismatch (Seeker: Alternance, Job: CDD)
#   Experience: 29y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $117,600.0 vs Job Offer $65,000
#
# Seeker 8106 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Fisheries, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 18y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $77,700.0 vs Job Offer $75,000
#
# Seeker 8108 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Healthcare, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 33y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $140,400.0 vs Job Offer $75,000
#
# Seeker 8109 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: teamwork, python
#   Sector: Mismatch (Seeker: Fisheries, Job: Data Science)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 9y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $68,600.0 vs Job Offer $65,000
#
# Seeker 8110 → Job DEV-001
#   Skills: 1/3 matched
#   Missing Skills: hysys, communication
#   Sector: Mismatch (Seeker: Media & Entertainment, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 6y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $78,700.0 vs Job Offer $75,000
#
# Seeker 8115 → Job DATA-002
#   Skills: 1/3 matched
#   Missing Skills: teamwork, python
#   Sector: Mismatch (Seeker: Transport & Logistics, Job: Data Science)
#   Contract: Mismatch (Seeker: Stage, Job: CDD)
#   Experience: 27y (Req: 2y)
#   Education: Master (Req: Bachelor)
#   Salary: Seeker $112,700.0 vs Job Offer $65,000
#
# Seeker 8119 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Public Sector, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 27y (Req: 3y)
#   Education: License (Req: License)
#   Salary: Seeker $96,600.0 vs Job Offer $75,000
#
# Seeker 8120 → Job DEV-001
#   Skills: 2/3 matched
#   Missing Skills: hysys
#   Sector: Mismatch (Seeker: Education, Job: Energy & Petroleum)
#   Contract: Mismatch (Seeker: Freelance, Job: CDD)
#   Experience: 27y (Req: 3y)
#   Education: Master (Req: License)
#   Salary: Seeker $96,600.0 vs Job Offer $75,000
#
# Top Candidates per Job:
#
# Job DEV-001 (Energy & Petroleum):
# 1. [Score: 83.47%] project management, problem solving, well logging, critical thinking, hysys, arabic/french bilingual, strategic planning, reservoir simulation, team leadership, communication, conflict resolution, microsoft office
#    Sector: Energy & Petroleum | Exp: 28y | Edu: Master
#    Matching Skills: problem solving, hysys, communication
# 2. [Score: 80.05%] well logging, reservoir simulation, problem solving, petrel software, critical thinking, arabic/french bilingual, strategic planning, communication, hysys, team leadership, report writing, geological modeling
#    Sector: Energy & Petroleum | Exp: 28y | Edu: License
#    Matching Skills: problem solving, hysys, communication
# 3. [Score: 79.92%] geological modeling, hysys, communication, negotiation, problem solving, presentation skills, conflict resolution, drilling optimization, time management, arabic/french bilingual, petrel software, well logging
#    Sector: Energy & Petroleum | Exp: 31y | Edu: License
#    Matching Skills: problem solving, hysys, communication
# 4. [Score: 67.10%] negotiation, team leadership, presentation skills, well logging, conflict resolution, geological modeling, project management, communication, critical thinking, teamwork, hysys
#    Sector: Energy & Petroleum | Exp: 12y | Edu: Master
#    Matching Skills: hysys, communication
# 5. [Score: 66.69%] communication, strategic planning, presentation skills, time management, team leadership, hysys, petrel software, drilling optimization, project management, conflict resolution, negotiation, enhanced oil recovery
#    Sector: Energy & Petroleum | Exp: 17y | Edu: Master
#    Matching Skills: hysys, communication
#
# Job DATA-002 (Data Science):
# 1. [Score: 75.21%] microservices, python, agile methodology, adaptability, problem solving, git, project management, spring boot, .net, teamwork, ci/cd pipelines, presentation skills
#    Sector: Information Technology | Exp: 20y | Edu: Master
#    Matching Skills: problem solving, python, teamwork
# 2. [Score: 53.75%] report writing, time management, python, teamwork, communication, negotiation, critical thinking, strategic planning, spring boot, agile methodology, adaptability, project management
#    Sector: Information Technology | Exp: 14y | Edu: Master
#    Matching Skills: teamwork, python
# 3. [Score: 52.83%] teamwork, conflict resolution, critical thinking, strategic planning, microsoft office, adaptability, spring boot, .net, project management, report writing, python, java
#    Sector: Information Technology | Exp: 21y | Edu: Master
#    Matching Skills: teamwork, python
# 4. [Score: 52.20%] project management, ci/cd pipelines, report writing, agile methodology, team leadership, problem solving, java, python, critical thinking, communication, django, conflict resolution
#    Sector: Information Technology | Exp: 30y | Edu: Master
#    Matching Skills: problem solving, python
# 5. [Score: 49.77%] team leadership, report writing, ci/cd pipelines, project management, time management, teamwork, python, .net, java, django, spring boot, presentation skills
#    Sector: Information Technology | Exp: 21y | Edu: License
#    Matching Skills: teamwork, python
